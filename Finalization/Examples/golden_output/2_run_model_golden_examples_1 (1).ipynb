# %% [markdown]
# # Tariikhna — Run Fine-Tuned Model (Golden Examples)
#
# Loads your fine-tuned model from Hugging Face and generates **complete** comic
# schemas for curated stories to showcase in your GP discussion.
#
# ### Pipeline for golden examples (NO Layer 1b):
# ```
# 1a  Split passage into narrative units
# 1c  Segment EVERY unit into scenes  (no 1b filtering - keep the whole story)
# 2   Generate schema (FINE-TUNED model)
# 3   Safety filter
# ```
# Layer 1b (selection) is removed so no part of the story is dropped.
#
# ### Setup:
# 1. Runtime -> Change runtime type -> **T4 GPU**
# 2. Have your HF repo ready (from the upload notebook)
# 3. A Groq API key for Layers 1a, 1c, 3 (base model tasks)

# %% [markdown]
# ## 1. Install

# %%
# !pip install unsloth groq -q
# !pip install --force-reinstall --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 39.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.6/915.6 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 113.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 802.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 127.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 110.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 114.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 103.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 116.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 21.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuda-python 12.9.7 requires cuda-bindings~=12.9.7, but you have cuda-bindings 12.9.4 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for unsloth (pyproject.toml) ... done

# %%
import torch
print(f'GPU: {torch.cuda.get_device_name(0)}')
print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB')
# Inference needs far less than training - T4 free tier is plenty
# Out:
# GPU: Tesla T4
# VRAM: 15.6 GB

# %% [markdown]
# ## 2. Load the Fine-Tuned Model From Hugging Face
#
# Loads base model + your adapters. ~5.5 GB total - fits easily on free T4.

# %%
from unsloth import FastLanguageModel

# ============================================
# OPTION A: Load from Hugging Face (your uploaded repo)
# ============================================
HF_REPO = 'MohamedShata/tariikhna-llama-3.1-8b-lora'

# If your repo is private, log in first:
# from huggingface_hub import login; login()

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = HF_REPO,        # your adapters - Unsloth auto-loads the base too
    max_seq_length = 2048,
    dtype = None,
    load_in_4bit = True,
)

# ============================================
# OPTION B: Load from a local zip (if not using HF)
# ============================================
# from google.colab import files
# uploaded = files.upload()  # upload tariikhna_lora.zip
# import zipfile; zipfile.ZipFile(list(uploaded.keys())[0]).extractall('tariikhna_lora')
# model, tokenizer = FastLanguageModel.from_pretrained(
#     model_name='tariikhna_lora', max_seq_length=2048, load_in_4bit=True)

# Switch to fast inference mode
FastLanguageModel.for_inference(model)
print('Fine-tuned model loaded and ready!')
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.6.9: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# Unsloth: Will load unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit as a legacy tokenizer.
# adapter_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]
# Unsloth 2026.6.9 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# Fine-tuned model loaded and ready!

# %% [markdown]
# ## 3. Layer 2 Generation Function (uses YOUR fine-tuned model)
#
# This is the layer you fine-tuned. It runs locally on the GPU - no API needed.

# %%
import json, re

# IMPORTANT: this MUST match the system prompt used during training, exactly.
# Best practice - load it straight from the training file so there is zero mismatch:
#   with open('tariikhna_training.jsonl', encoding='utf-8') as f:
#       LAYER_2_SYSTEM = json.loads(f.readline())['messages'][0]['content']
# The full trained prompt is pasted below so the notebook works standalone.

LAYER_2_SYSTEM = """You are a specialist in creating children's Islamic educational comics (ages 6-12) for the Tariikhna platform.

Convert ONE visual scene into a complete schema with a DETAILED image generation prompt.

=== ISLAMIC DEPICTION RULES (CRITICAL) ===
- Prophets: NEVER show face. Show ONLY from behind, distinguished by clothing (e.g. green cloak). In the image_prompt, refer to a prophet as 'the central figure seen from behind' or 'the man in the green cloak' - NEVER use the literal word 'prophet' in image_prompt.
- Women: always fully and modestly dressed (jilbab, khimar covering hair). Describe clothing, not body.
- Others (companions, antagonists, crowds): shown normally with faces.
- No graphic violence. No idols in detail. No modern objects.

=== IMAGE PROMPT: MUST BE 250-300 WORDS ===
Include ALL of:
1. Art style: 'Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12'
2. Setting: specific 7th century location, architecture, furnishings, objects
3. Each character: build, posture, clothing with SPECIFIC colors, what they are doing
4. The specific action/gesture/emotion
5. Lighting: source, direction, quality, color
6. Composition: shot type, camera angle
7. Color palette: dominant and accent colors
8. End with: 'No modern objects, historically accurate 7th century scene.'

=== PHRASING TO AVOID (prevents image filter rejections) ===
- 'prophet' in image_prompt -> 'the central figure' / 'the man in the green cloak'
- 'young girl/child' + body -> 'young woman' or describe clothing only
- 'face hidden/obscured/dark' -> 'seen from behind' / 'turned away'
- 'baby/infant' + body -> 'a swaddled bundle'

=== OUTPUT (JSON only) ===
{
  \"scene_title\": \"...\",
  \"era\": \"pre_islamic_prophets|ancient_prophets|pre_prophetic|early_makkah|late_makkah|madinah_early|madinah_late\",
  \"region\": \"makkah|madinah|arabian_desert|egypt_ancient|levant_ancient|sinai|abyssinia|other\",
  \"source_reference\": \"...\",
  \"moral_lesson\": \"...\",
  \"characters\": [{\"id\":\"...\",\"name\":\"...\",\"role\":\"prophet|sahabi|family_of_prophet|antagonist|supporting|crowd\",\"depiction_rule\":\"NO_FACE|FROM_BEHIND|SILHOUETTE|FULL\",\"appearance\":\"clothing and build, no facial features for prophets\"}],
  \"narrative_text\": \"1-3 simple child sentences\",
  \"compliance\": {\"prophet_check\":\"...\",\"modesty_check\":\"COMPLIANT|NEEDS_REVIEW\",\"child_safe\":\"APPROPRIATE|NEEDS_REVIEW\",\"notes\":\"...\"},
  \"image_prompt\": \"the 250-300 word detailed prompt\"
}
Output ONLY the JSON object."""

def extract_json(text):
    text = text.strip()
    text = re.sub(r'^```(?:json)?\s*', '', text)
    text = re.sub(r'\s*```$', '', text)
    candidates = [i for i in [text.find('{'), text.find('[')] if i >= 0]
    if candidates:
        text = text[min(candidates):]
    try:
        return json.loads(text)
    except:
        last = text.rfind('}')
        if last > 0:
            try: return json.loads(text[:last+1])
            except: pass
        return None

def layer_2_generate(scene, source_ref=''):
    """Generate schema using the FINE-TUNED model. User format MATCHES training exactly."""
    # Training used exactly: 'Generate the schema for this scene:\n\n' + scene JSON  (NO Source line)
    messages = [
        {'role': 'system', 'content': LAYER_2_SYSTEM},
        {'role': 'user', 'content': f'Generate the schema for this scene:\n\n{json.dumps(scene, indent=2)}'}
    ]
    inputs = tokenizer.apply_chat_template(
        messages, tokenize=True, add_generation_prompt=True,
        return_tensors='pt', return_dict=True
    ).to('cuda')
    input_len = inputs['input_ids'].shape[1]
    outputs = model.generate(
        input_ids=inputs['input_ids'],
        attention_mask=inputs['attention_mask'],
        max_new_tokens=1024,
        temperature=0.6,
        use_cache=True,
        pad_token_id=tokenizer.eos_token_id
    )
    # Decode ONLY the newly generated tokens (not the prompt)
    generated_tokens = outputs[0][input_len:]
    generated = tokenizer.decode(generated_tokens, skip_special_tokens=True)
    return extract_json(generated)

print('Layer 2 (fine-tuned) ready - prompt and format matched to training!')
# Out:
# Layer 2 (fine-tuned) ready - prompt and format matched to training!

# %% [markdown]
# ## 4. Layers 1a, 1c, 3 (base model via Groq)
#
# Note: NO Layer 1b - we keep every narrative unit for complete stories.

# %%
from groq import Groq
import time

GROQ_KEY = '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'
groq_client = Groq(api_key=GROQ_KEY)
GROQ_MODEL = 'llama-3.1-8b-instant'

def call_groq(system, user, max_tokens=2048, temp=0.4):
    for _ in range(5):
        try:
            r = groq_client.chat.completions.create(
                model=GROQ_MODEL,
                messages=[{'role':'system','content':system},{'role':'user','content':user}],
                max_tokens=max_tokens, temperature=temp)
            return r.choices[0].message.content
        except Exception as e:
            if '429' in str(e) or 'rate' in str(e).lower():
                print('  rate limited, waiting 30s'); time.sleep(30)
            else:
                print(f'  error: {str(e)[:80]}'); time.sleep(5)
    return None

LAYER_1A_SYSTEM = """You are a narrative analyst for Islamic historical texts. Split the passage into DISTINCT NARRATIVE UNITS (self-contained mini-stories). Output a JSON array; each unit has: unit_number, unit_title, unit_text, main_characters (array), event_summary. Output ONLY the JSON array."""

LAYER_1C_SYSTEM = """You are a comic storyboard artist for children's Islamic education (ages 6-12). Break ONE narrative unit into individual VISUAL SCENES (one moment = one panel). Output a JSON array; each scene has: scene_number, scene_summary, key_visual_action, characters_present (array), setting, emotional_tone, time_of_day. Output ONLY the JSON array."""

LAYER_3_SYSTEM = """You are a content safety reviewer. Rewrite the image prompt to avoid NSFW-filter trigger words WITHOUT changing the scene or removing detail. Replace: 'prophet'->'the central figure'; 'young girl/child'+body->'young woman'; 'face hidden/obscured'->'seen from behind'; 'baby/infant'+body->'a swaddled bundle'. Output JSON: {\"cleaned_prompt\": \"...\", \"changes_made\": [...]}. Output ONLY JSON."""

def layer_1a(passage):
    return extract_json(call_groq(LAYER_1A_SYSTEM, f'Split this passage:\n\n{passage}'))

def layer_1c(unit):
    return extract_json(call_groq(LAYER_1C_SYSTEM, f'Break into scenes:\n\n{json.dumps(unit, indent=2)}'))

def layer_3(image_prompt):
    r = extract_json(call_groq(LAYER_3_SYSTEM, f'Clean this prompt:\n\n{image_prompt}', max_tokens=1024, temp=0.2))
    if r and 'cleaned_prompt' in r:
        return r['cleaned_prompt'], r.get('changes_made', [])
    return image_prompt, []

print('Layers 1a, 1c, 3 ready (Layer 1b intentionally removed)!')
# Out:
# Layers 1a, 1c, 3 ready (Layer 1b intentionally removed)!

# %% [markdown]
# ## 5. Story Context Generator (for the UI narration)
#
# Generates reader-facing text: a title, an introduction, and a closing lesson.
# This is the context shown alongside the images in the interface so readers
# understand the story, not just see pictures.

# %%
STORY_CONTEXT_SYSTEM = """You are writing reader-facing text for a children's Islamic comic (ages 6-12).
Given a story passage, produce warm, simple, engaging framing text for young readers.

Output JSON:
{
  "story_title": "a warm, child-friendly title (not the academic heading)",
  "introduction": "2-3 simple sentences setting up the story, drawing the child in",
  "conclusion": "2-3 sentences closing the story warmly",
  "moral_lesson": "one clear lesson a child can take away, in simple words",
  "reading_age": "6-9 or 8-12",
  "key_figures": ["list of main people in the story"]
}
Keep language simple, warm, and age-appropriate. Output ONLY the JSON."""

def generate_story_context(passage, source_ref=''):
    """Generate the reader-facing framing text for the whole story."""
    raw = call_groq(STORY_CONTEXT_SYSTEM, f'Write reader framing for this story:\n\n{passage}', max_tokens=1024, temp=0.6)
    return extract_json(raw)

print('Story context generator ready!')
# Out:
# Story context generator ready!

# %% [markdown]
# ## 6. Golden-Example Pipeline (1a -> 1c -> 2 -> 3, every unit kept)
#
# Now also generates story context so each panel image has reader text alongside it.

# %%
def generate_golden_story(passage, source_ref='', verbose=True):
    """Generate a COMPLETE story with reader context - no unit dropped (no Layer 1b)."""
    result = {'passage': passage, 'source': source_ref, 'story_context': None, 'units': None, 'panels': []}

    # Story-level context first (for the UI narration)
    if verbose: print('Generating story context (title, intro, lesson)...')
    result['story_context'] = generate_story_context(passage, source_ref)
    if result['story_context'] and verbose:
        print(f'  Title: {result["story_context"].get("story_title", "?")}')
    time.sleep(2)

    if verbose: print('Layer 1a: splitting into units...')
    units = layer_1a(passage)
    if not units:
        print('  FAILED at 1a'); return result
    result['units'] = units
    if verbose: print(f'  {len(units)} units found (ALL kept)')
    time.sleep(2)

    panel_number = 0
    # NO Layer 1b - iterate over EVERY unit
    for u_idx, unit in enumerate(units):
        if verbose: print(f'\nUnit {u_idx+1}: {unit.get("unit_title", "?")}')
        scenes = layer_1c(unit)
        if not scenes:
            if verbose: print('  segmentation failed, skipping unit')
            continue
        if verbose: print(f'  {len(scenes)} scenes')
        time.sleep(2)

        for scene in scenes:
            schema = layer_2_generate(scene, source_ref)

            # Validation: check for image_prompt (the field that actually matters).
            # The trained format leads with scene_number/scene_summary and has NO scene_title - that's expected.
            if not schema or 'image_prompt' not in schema:
                if verbose: print('    scene failed (no image_prompt), skipping')
                continue

            # Drop the echoed input fields for a cleaner saved schema (cosmetic)
            for redundant in ['scene_number', 'scene_summary']:
                schema.pop(redundant, None)

            # Layer 3 safety filter on the image prompt
            cleaned, changes = layer_3(schema['image_prompt'])
            schema['image_prompt'] = cleaned
            schema['_safety_changes'] = changes

            panel_number += 1
            # Each panel carries the image prompt AND reader-facing narration
            result['panels'].append({
                'panel_number': panel_number,
                'unit_title': unit.get('unit_title', ''),
                'scene_input': scene,
                'narrative_text': schema.get('narrative_text', ''),   # reader text for UI
                'moral_lesson': schema.get('moral_lesson', ''),
                'image_prompt': schema.get('image_prompt', ''),
                'characters': schema.get('characters', []),
                'compliance': schema.get('compliance', {}),
                'era': schema.get('era', ''),
                'region': schema.get('region', ''),
                'full_schema': schema
            })
            if verbose:
                wc = len(schema.get('image_prompt', '').split())
                title = schema.get('narrative_text', '')[:45]
                print(f'    Panel {panel_number}: {title}... ({wc}w prompt)')

    if verbose: print(f'\nComplete story: {len(result["panels"])} panels with narration')
    return result

print('Golden-example pipeline ready (validation matched to trained format)!')
# Out:
# Golden-example pipeline ready (validation matched to trained format)!

# %% [markdown]
# ## 7. Select & Generate Your Golden Stories
#
# Four curated complete-episode stories selected for the GP discussion.

# %%
# Load the 4 selected golden passages (upload golden_passages_selected.json)
import json
with open('golden_passages_selected.json', encoding='utf-8') as f:
    GOLDEN_PASSAGES = json.load(f)

print(f'{len(GOLDEN_PASSAGES)} golden stories loaded:')
for p in GOLDEN_PASSAGES:
    print(f'  {p["display_title"]} ({len(p["passage"].split())}w)')
# Out:
# 4 golden stories loaded:
#   A Transfer of Care (1125w)
#   The First Muslim Man (945w)
#   Abū Bakr’s Noble Heart (851w)
#   Compassion (235w)

# %%
import os
os.makedirs('golden_output', exist_ok=True)

golden_results = []
for i, p in enumerate(GOLDEN_PASSAGES):
    print(f'\n{"="*60}')
    print(f'GOLDEN STORY {i+1}/{len(GOLDEN_PASSAGES)}: {p["display_title"]}')
    print(f'{"="*60}')
    res = generate_golden_story(p['passage'], p.get('source', ''), verbose=True)
    res['passage_id'] = p['passage_id']
    res['display_title'] = p['display_title']
    golden_results.append(res)
    with open(f'golden_output/{p["passage_id"]}.json', 'w', encoding='utf-8') as f:
        json.dump(res, f, ensure_ascii=False, indent=2)

print(f'\n\nDONE! {len(golden_results)} stories, {sum(len(r["panels"]) for r in golden_results)} total panels.')
# Out:
# ============================================================
# GOLDEN STORY 1/4: A Transfer of Care
# ============================================================
# Generating story context (title, intro, lesson)...
#   Title: Muhammad's Loving Caretakers
# Layer 1a: splitting into units...
#   9 units found (ALL kept)
#
# Unit 1: Abd al-Muṭṭalib's Concern for Muhammad's Future
#   rate limited, waiting 30s
#   4 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 1: Abd al-Muṭṭalib sat on his bed, feeling worri... (82w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 2: Abd al-Muḥd ibn al-Ḥaḍīd calls out to Abū Ḥāṭ... (88w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 3: Abd al-Muṭṭalib asks Abū Ṭālib to take care o... (94w prompt)
#     Panel 4: Abū Ḥakīm agreed to care for Muhammad, just a... (110w prompt)
#
# Unit 2: Muhammad's Grief over ʿ Abd al-Muṭṭalib's Death
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 5: Muhammad was deeply saddened by the news of h... (78w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 6: Muhammad visits his grandfather's grave, reme... (164w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 7: Muhammad sat in his home, surrounded by the q... (114w prompt)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 8: Muhammad prayed for his grandfather's soul, s... (82w prompt)
#     Panel 9: Muhammad felt sad and alone after the loss of... (125w prompt)
#
# Unit 3: Abū Ṭālib's Care for Muhammad
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 10: Abu Talib was surprised to find Muhammad play... (106w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 11: Abu Talib called out to his nephew Muhammad, ... (93w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 12: Abu Talib cared for his nephew Muhammad by fe... (150w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 13: Abu Talib was Muhammad's uncle and a kind man... (113w prompt)
#     Panel 14: Abu Talib took Muhammad on a journey to trade... (123w prompt)
#
# Unit 4: Abū Ṭālib's Support for Muhammad's Message
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 15: Abū Ṭālib listened carefully as Muhammad shar... (108w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 16: Muhammad shared his message with Abū Ḥabīb, w... (115w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 17: Abū Ḥakīm saw Muhammad's sadness and decided ... (176w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 18: The people of Quraysh were angry when they he... (117w prompt)
#     Panel 19: Abū Ṭālib stood by Muhammad's side, even when... (127w prompt)
#
# Unit 5: Signs of God's Blessings in Muhammad's Presence
#   6 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 20: Abū Ṭālib's household is struggling to make e... (91w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 21: Muhammad arrives at Abū Ḥālib's home, seeking... (118w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 22: Abū Ṭālib looked at Muhammad with a worried e... (107w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 23: Muhammad offered to pray for blessings, showi... (108w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 24: Abū Ṭālib was amazed as food suddenly appeare... (147w prompt)
#     Panel 25: Abū Ṭālib's household was once poor, but now ... (129w prompt)
#
# Unit 6: Muhammad's Encounter with the Fortune-Teller
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 26: Al-Ḥaḍramah took Muhammad to meet the fortune... (67w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 27: The fortune-teller, known for his cunning way... (127w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 28: The fortune-teller, a skilled but misguided i... (98w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 29: The fortune-teller spoke to Muhammad in a ser... (158w prompt)
#     Panel 30: After visiting the fortune-teller, Al-Ḥaḍrama... (78w prompt)
#
# Unit 7: Muhammad's Encounter with the Christian Monk Baḥīrā
#   4 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 31: Abu al-Hasan and Muhammad set out on their jo... (89w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 32: Abu al-Hasan and Muhammad arrived in Syria, e... (153w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 33: After completing their business in Syria, Abu... (111w prompt)
#     Panel 34: Ba'ura invited Abu al-Hasan and Muhammad to d... (105w prompt)
#
# Unit 8: Baḥīrā's Recognition of Muhammad's Prophetic Status
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 35: Baḥīrā had always been curious about the worl... (89w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 36: Baṭṭarāʿ approached Muhammad with a curious e... (88w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 37: Baḥīrā saw the mark on Muhammad's shoulder an... (106w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 38: Baṭṭah nodded in confirmation, acknowledging ... (80w prompt)
#     Panel 39: Baḥīrā, a respected elder, offers guidance to... (84w prompt)
#
# Unit 9: Muhammad's Sense of Responsibility towards Abū Ṭālib
#   4 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 40: Muhammad rode his camel through the desert, r... (142w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 41: Muhammad saw the poverty of his uncle's famil... (113w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 42: Muhammad felt a sense of responsibility towar... (81w prompt)
#     Panel 43: Muhammad sat in his home, thinking about his ... (124w prompt)
#
# Complete story: 43 panels with narration
#
# ============================================================
# GOLDEN STORY 2/4: The First Muslim Man
# ============================================================
# Generating story context (title, intro, lesson)...
#   Title: Zayd's Big Choice
# Layer 1a: splitting into units...
#   FAILED at 1a
#
# ============================================================
# GOLDEN STORY 3/4: Abū Bakr’s Noble Heart
# ============================================================
# Generating story context (title, intro, lesson)...
#   Title: Abū Bakr's Kind Heart
# Layer 1a: splitting into units...
#   9 units found (ALL kept)
#
# Unit 1: Abū Bakr's Noble Action
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 1: Abu Bakr was deeply concerned when he heard t... (116w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 2: Abu Bakr met with al-Hafayl ibn Abdulla al-As... (117w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 3: Abu Bakr was pleased to buy 'Amir ibn Fuhayra... (165w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 4: Abu Bakr stood tall, his eyes shining with de... (179w prompt)
#     Panel 5: Abu Bakr and 'Amir ibn Fuhayrah met and becam... (144w prompt)
#
# Unit 2: Abū Bakr Helps the Prophet
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 6: The Prophet sat in the cave, deep in thought.... (88w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 7: Abu Bakr was deeply concerned when he heard a... (76w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 8: Abu Bakr and the Prophet were excitedly prepa... (197w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 9: Abu Bakr and the Prophet were riding their ca... (101w prompt)
#     Panel 10: Abu Bakr and the Prophet rode their camels in... (141w prompt)
#
# Unit 3: Abū Bakr's Action with Zunayrah
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 11: Abu Bakr watched in horror as Abu Jahl tortur... (111w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 12: Abu Bakr stood tall in the desert, his heart ... (114w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 13: Abu Bakr stood tall, looking Abu Jahl straigh... (111w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 14: Abu Bakr saw Zunayrah being mistreated and de... (107w prompt)
#     Panel 15: Zunayrah was overjoyed when Abu Bakr freed he... (124w prompt)
#
# Unit 4: Abū Bakr Rescues Al-Nahdiyah and Her Daughter
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 16: Abu Bakr heard about the mistreatment of al-N... (114w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 17: Abu Bakr sat in quiet contemplation, weighing... (99w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 18: Abu Bakr was relieved to finally buy al-Nahdi... (130w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 19: Al-Nahdiyah and her daughter were finally fre... (86w prompt)
#     Panel 20: Abu Bakr welcomed al-Nahdiyah and her daughte... (184w prompt)
#
# Unit 5: Abū Bakr Frees Umm ʿ Ubays
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 21: Abu Bakr watched in the distance as Umm Ubays... (106w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 22: Abu Bakr decided to buy Umm Ubays from her ma... (128w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 23: Abu Bakr was overjoyed to have rescued Umm Ub... (205w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 24: Abu Bakr, the faithful companion of the Proph... (139w prompt)
#     Panel 25: Umm Ubays was overjoyed when Abu Bakr freed h... (146w prompt)
#
# Unit 6: Abū Bakr Frees Another Slave
#   6 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 26: Abu Bakr was known for his kindness and gener... (82w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 27: Abu Bakr listened with concern as a Muslim sh... (118w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 28: Abu Bakr was known for his kindness and compa... (119w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 29: Abu Bakr was relieved to finally buy the slav... (144w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 30: Abu Bakr was so moved by the Prophet's words ... (103w prompt)
#     Panel 31: Umar ibn al-Khatab looked unhappy and disappr... (95w prompt)
#
# Unit 7: Abū Bakr's Father Disapproves
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 32: Abu Bakr showed great kindness by setting fre... (128w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 33: Abu Bakr's father was surprised to see him fr... (107w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 34: Abu Bakr's father was not happy with his choi... (128w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 35: Abu Bakr's father looked at him with a puzzle... (88w prompt)
#     Panel 36: Abu Bakr's father looked at him with disappoi... (116w prompt)
#
# Unit 8: Abū Bakr's Exemplary Action
#   6 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 37: The Prophet Muhammad stood in the Prophet's M... (127w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 38: Abu Bakr was taken aback when the Prophet ask... (84w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 39: The Prophet Muhammad smiled reassuringly at A... (133w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 40: Abu Bakr listened to the Prophet's words and ... (136w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 41: Abu Bakr was known for his kindness and fairn... (97w prompt)
#     Panel 42: The followers of the new religion are inspire... (98w prompt)
#
# Unit 9: ʿ Umar's Praise for Abū Bakr
#   4 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 43: Abu Bakr saw Bilal's potential and decided to... (87w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 44: Abu Bakr was known for his kindness and selfl... (92w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 45: The Prophet's loyal companion, ʿ Umar, thinks... (90w prompt)
#     Panel 46: The Prophet's trusted companion, ʿ Umar, prai... (77w prompt)
#
# Complete story: 46 panels with narration
#
# ============================================================
# GOLDEN STORY 4/4: Compassion
# ============================================================
# Generating story context (title, intro, lesson)...
#   Title: Bilal's Kindness Test
# Layer 1a: splitting into units...
#   4 units found (ALL kept)
#
# Unit 1: Bilāl's Incident
#   4 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 1: Bilāl is planning his route to pass by the bu... (119w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 2: The Prophet's cousin, Bilāl, was joining the ... (169w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 3: Bilāl and the women set off on their journey,... (135w prompt)
#     Panel 4: When Ṣafiyyah saw the burial site, she starte... (115w prompt)
#
# Unit 2: The Prophet's Reproof
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 5: Bilāl led Ḥāṭib and her cousin through the de... (89w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 6: When Bilāl saw the burial site, he began to c... (106w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 7: The Prophet approached Bilāl, looking disappr... (78w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 8: The Prophet looked at Bilāl with a stern expr... (135w prompt)
#     Panel 9: The Prophet looked at Bilāl with kindness, bu... (184w prompt)
#
# Unit 3: Bilāl's Apology
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 10: The Prophet looked at Bilāl with a stern expr... (108w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 11: Bilāl felt ashamed of his actions and looked ... (97w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 12: Bilāl sat in contemplation, thinking deeply a... (81w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 13: Bilāl felt sorry for his actions and wanted t... (138w prompt)
#     Panel 14: The Prophet looked at Bilal with a serious ex... (97w prompt)
#
# Unit 4: The Prophet's Teaching
#   5 scenes
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 15: The Prophet saw his companion being harsh wit... (117w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 16: The Prophet gently yet firmly reproached his ... (143w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 17: The Prophet stood in the marketplace, surroun... (92w prompt)
# Both `max_new_tokens` (=1024) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#     Panel 18: The Prophet's words touched the companion's h... (118w prompt)
#     Panel 19: The Prophet and his companion visited the Jew... (102w prompt)
#
# Complete story: 19 panels with narration
#
#
# DONE! 4 stories, 108 total panels.

# %% [markdown]
# ## 8. Inspect: Each Panel With Its Reader Narration

# %%
for res in golden_results:
    ctx = res.get('story_context') or {}
    print(f'\n{"="*65}')
    print(f'STORY: {ctx.get("story_title", res["display_title"])}')
    print(f'{"="*65}')
    print(f'Introduction: {ctx.get("introduction", "")}')
    print(f'Lesson: {ctx.get("moral_lesson", "")}')
    print(f'Panels: {len(res["panels"])}')
    print('-'*65)
    for panel in res['panels']:
        print(f'\n  PANEL {panel["panel_number"]}')
        print(f'  Reader text: {panel["narrative_text"]}')
        print(f'  Image prompt ({len(panel["image_prompt"].split())}w): {panel["image_prompt"][:160]}...')
    print(f'\nConclusion: {ctx.get("conclusion", "")}')
# Out:
# =================================================================
# STORY: Muhammad's Loving Caretakers
# =================================================================
# Introduction: Imagine being a young boy, living with your loving uncle after your grandfather has passed away. This is the story of Muhammad, a boy who would grow up to be a great Prophet. His uncle, Abū Ṭālib, took care of him and showed him kindness and love.
# Lesson: The importance of kindness and love in our relationships with others. Just like Abū Ṭālib showed love and care to Muhammad, we can show love and care to those around us, making a positive impact on their lives.
# Panels: 43
# -----------------------------------------------------------------
#
#   PANEL 1
#   Reader text: Abd al-Muṭṭalib sat on his bed, feeling worried about his future. He thought about his mortality and what would happen to him after he died.
#   Image prompt (82w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Show the central figure of Islam's early history sitting on a simple b...
#
#   PANEL 2
#   Reader text: Abd al-Muḥd ibn al-Ḥaḍīd calls out to Abū Ḥāṭib, concerned about his safety.
#   Image prompt (88w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a quiet, serene domestic setting, Abd al-Muḥd ibn al-Ḥaḍīd stands i...
#
#   PANEL 3
#   Reader text: Abd al-Muṭṭalib asks Abū Ṭālib to take care of his uncle Muhammad.
#   Image prompt (94w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a cozy home with a warm glow of light. The central...
#
#   PANEL 4
#   Reader text: Abū Ḥakīm agreed to care for Muhammad, just as Abū Ṭālib had done before him.
#   Image prompt (110w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: The central figure's home, a simple yet cozy space with a few...
#
#   PANEL 5
#   Reader text: Muhammad was deeply saddened by the news of his grandfather's passing. He remembered the wise counsel and guidance his grandfather had given him.
#   Image prompt (78w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The central figure's home, a simple yet cozy space with a few furnishi...
#
#   PANEL 6
#   Reader text: Muhammad visits his grandfather's grave, remembering the lessons he taught him and the love they shared.
#   Image prompt (164w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure stands with his hands clasped together in a gentle ...
#
#   PANEL 7
#   Reader text: Muhammad sat in his home, surrounded by the quiet of the night. As he reflected on his life, a warm smile spread across his face as he remembered his grandfather's kindness.
#   Image prompt (114w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a cozy dimly lit room, the central figure sits on a simple bench or...
#
#   PANEL 8
#   Reader text: Muhammad prayed for his grandfather's soul, seeking guidance and comfort from Allah.
#   Image prompt (82w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure is shown from behind, bowed in prayer, with his han...
#
#   PANEL 9
#   Reader text: Muhammad felt sad and alone after the loss of his dear friend. But when he was with his family, he felt comfort and love.
#   Image prompt (125w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A warm and cozy night scene in the central figure's home, with the cen...
#
#   PANEL 10
#   Reader text: Abu Talib was surprised to find Muhammad playing outside the Ka'bah. He smiled at the sight of his nephew's carefree joy.
#   Image prompt (106w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Outside the Ka'bah in Mecca: a simple white thobe and a plain brown wo...
#
#   PANEL 11
#   Reader text: Abu Talib called out to his nephew Muhammad, inviting him to come and eat.
#   Image prompt (93w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: a sunny afternoon outside the Ka'bah in Mecca, with palm tree...
#
#   PANEL 12
#   Reader text: Abu Talib cared for his nephew Muhammad by feeding him a meal, showing the importance of family and care for one another.
#   Image prompt (150w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In the home of Abu Talib in Mecca, a warm and cozy evening setting wit...
#
#   PANEL 13
#   Reader text: Abu Talib was Muhammad's uncle and a kind man who taught him how to read and write. Muhammad was very grateful to have such a loving teacher.
#   Image prompt (113w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In the home of Abu Talib in Mecca, a warm and inviting space with a la...
#
#   PANEL 14
#   Reader text: Abu Talib took Muhammad on a journey to trade goods, showing him the importance of commerce in building relationships.
#   Image prompt (123w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A desert road in Mecca, with palm trees and rocks in the back...
#
#   PANEL 15
#   Reader text: Abū Ṭālib listened carefully as Muhammad shared his message, his face a picture of concern and curiosity.
#   Image prompt (108w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. A quiet room in a family member's home, with a simple wooden table and...
#
#   PANEL 16
#   Reader text: Muhammad shared his message with Abū Ḥabīb, who listened intently.
#   Image prompt (115w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure speaking, with Abū Ḥabīb listening intently, in a q...
#
#   PANEL 17
#   Reader text: Abū Ḥakīm saw Muhammad's sadness and decided to offer his support. He placed a comforting hand on Muhammad's shoulder, saying, 'Do not worry, Muhammad. We will face this challenge together.' Muhammad felt grateful for Abū Ḥakīm's kindness and encouragement.
#   Image prompt (176w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a quiet room in the central figure's home, the central figure is sh...
#
#   PANEL 18
#   Reader text: The people of Quraysh were angry when they heard Muhammad's message. They didn't want to listen to him.
#   Image prompt (117w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. A public square in Mecca, with a large stone or concrete pavement and ...
#
#   PANEL 19
#   Reader text: Abū Ṭālib stood by Muhammad's side, even when faced with opposition from their community.
#   Image prompt (127w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a public square in Mecca, Abū Ṭālib and Muhammad stand together, lo...
#
#   PANEL 20
#   Reader text: Abū Ṭālib's household is struggling to make ends meet. The family is shown sharing what little they have, demonstrating the importance of kindness and generosity in times of need.
#   Image prompt (91w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene shows the central figure's home, with an empty table in the ...
#
#   PANEL 21
#   Reader text: Muhammad arrives at Abū Ḥālib's home, seeking to meet with him and share his message.
#   Image prompt (118w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The central figure, Muhammad, is shown from behind, wearing a deep gre...
#
#   PANEL 22
#   Reader text: Abū Ṭālib looked at Muhammad with a worried expression, 'I'm afraid we don't have much food to offer, son.' Muhammad nodded understandingly, 'It's okay, Abū Ṭālib, we can share what little we have.'
#   Image prompt (107w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: The home of Abū Ṭālib, a simple yet cozy dwelling in pre-Isla...
#
#   PANEL 23
#   Reader text: Muhammad offered to pray for blessings, showing his compassion and kindness towards Abū Ṭālib.
#   Image prompt (108w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a 7th century home, with a simple wooden door and ...
#
#   PANEL 24
#   Reader text: Abū Ṭālib was amazed as food suddenly appeared on the table, filling their plates and bowls. Muhammad smiled, knowing that Allah had provided for them.
#   Image prompt (147w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a cozy domestic setting, Abū Ṭālib and Muhammad sit at a wooden tab...
#
#   PANEL 25
#   Reader text: Abū Ṭālib's household was once poor, but now it was filled with abundance. Muhammad felt grateful for the blessings they received.
#   Image prompt (129w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a spacious, well-lit room, a large wooden table is set with a white...
#
#   PANEL 26
#   Reader text: Al-Ḥaḍramah took Muhammad to meet the fortune-teller, who lived in a small house on the outskirts of the desert town.
#   Image prompt (67w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. A desert street with a small house in the background. A central figure...
#
#   PANEL 27
#   Reader text: The fortune-teller, known for his cunning ways, greeted Al-Mughira and Muhammad with a bow, trying to hide his true intentions.
#   Image prompt (127w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: Inside the central figure's house, with a simple wooden door ...
#
#   PANEL 28
#   Reader text: The fortune-teller, a skilled but misguided individual, prepares to divine Muhammad's future using their crystal ball and candles. Muhammad, steadfast in his faith, remains calm and composed, while Al-Mughira looks on with a mixture of curiosity and concern.
#   Image prompt (98w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set inside the fortune-teller's house, with a warm, golde...
#
#   PANEL 29
#   Reader text: The fortune-teller spoke to Muhammad in a serious tone, 'Your future is shrouded in mystery, but one thing is certain, you will face great challenges and triumphs.' Muhammad's expression remained calm, but his eyes betrayed a hint of uncertainty.
#   Image prompt (158w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Inside the central figure's house, a medium-sized room with a low ceil...
#
#   PANEL 30
#   Reader text: After visiting the fortune-teller, Al-Ḥaḍramah and Muhammad decided to leave, feeling confused and unsure about the future.
#   Image prompt (78w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert street with the central figure's house in...
#
#   PANEL 31
#   Reader text: Abu al-Hasan and Muhammad set out on their journey to Syria, feeling excited and determined to fulfill their mission.
#   Image prompt (89w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene shows a central figure and Muhammad riding camels in a deser...
#
#   PANEL 32
#   Reader text: Abu al-Hasan and Muhammad arrived in Syria, eager to explore the bustling market and learn about its people and culture.
#   Image prompt (153w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a bustling market in ancient Syria, Abu al-Hasan and the central fi...
#
#   PANEL 33
#   Reader text: After completing their business in Syria, Abu al-Hasan and Muhammad packed their belongings, feeling relieved and prepared to leave.
#   Image prompt (111w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A cozy room in a Syrian inn, with a simple wooden bed, a few ...
#
#   PANEL 34
#   Reader text: Ba'ura invited Abu al-Hasan and Muhammad to dinner at his home in the desert, showing his hospitality and kindness.
#   Image prompt (105w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The central figure's home in the desert: a simple one-room dwelling wi...
#
#   PANEL 35
#   Reader text: Baḥīrā had always been curious about the world around him. One day, he met a man who would change his life forever.
#   Image prompt (89w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The desert landscape stretches out before us, with Baḥīrā and the cent...
#
#   PANEL 36
#   Reader text: Baṭṭarāʿ approached Muhammad with a curious expression, pointing at him as if to ask, 'Tell me about your life, Muhammad.' Muhammad smiled, ready to share his story.
#   Image prompt (88w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The desert landscape stretches out in the background, with Baṭṭarāʿ st...
#
#   PANEL 37
#   Reader text: Baḥīrā saw the mark on Muhammad's shoulder and knew it was a sign from Allah.
#   Image prompt (106w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A sandy desert landscape with a few palm trees in the distanc...
#
#   PANEL 38
#   Reader text: Baṭṭah nodded in confirmation, acknowledging Muhammad as the last Prophet.
#   Image prompt (80w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: In the desert, the central figure stands with his hands clasped togeth...
#
#   PANEL 39
#   Reader text: Baḥīrā, a respected elder, offers guidance to Muhammad, pointing the way forward with a gentle expression.
#   Image prompt (84w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The desert landscape stretches out before the central figure and Baḥīr...
#
#   PANEL 40
#   Reader text: Muhammad rode his camel through the desert, reflecting on the spiritual journey he had just completed. He felt a sense of peace and clarity wash over him.
#   Image prompt (142w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In the distance, a camel is seen riding towards a palm tree-lined oasi...
#
#   PANEL 41
#   Reader text: Muhammad saw the poverty of his uncle's family and felt concerned about their well-being.
#   Image prompt (113w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In the early morning scene, the central figure is shown looking at his...
#
#   PANEL 42
#   Reader text: Muhammad felt a sense of responsibility towards his uncle, Abu Talib. He wanted to make sure his uncle was taken care of.
#   Image prompt (81w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure sits in a cozy corner of his home, surrounded by wa...
#
#   PANEL 43
#   Reader text: Muhammad sat in his home, thinking about his uncle's family who needed his help.
#   Image prompt (124w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure sits in his home, surrounded by simple furnishings ...
#
# Conclusion: Muhammad was grateful for his uncle's love and care. He knew that he was lucky to have someone like Abū Ṭālib in his life. And as we can see, Abū Ṭālib's love and care for Muhammad had a special impact on those around them.
#
# =================================================================
# STORY: Zayd's Big Choice
# =================================================================
# Introduction: A long time ago, there was a kind and brave boy named Zayd. He was a slave, but he was loved by a very special man named the Prophet Muhammad. One day, Zayd's father came to visit him, and he asked the Prophet to let Zayd go back home. But Zayd had a big decision to make.
# Lesson: The moral of Zayd's story is that loyalty and love can be stronger than family ties, and that making sacrifices for what is right can lead to great rewards.
# Panels: 0
# -----------------------------------------------------------------
#
# Conclusion: Zayd chose to stay with the Prophet, and it was a decision that would change his life forever. He learned from the Prophet's kindness and integrity, and he became one of the first people to believe in Islam. Zayd's story teaches us that sometimes, the hardest choices can lead us to the best outcomes.
#
# =================================================================
# STORY: Abū Bakr's Kind Heart
# =================================================================
# Introduction: Once upon a time, in a city called Makkah, there lived a kind and brave man named Abū Bakr. He loved helping those in need and standing up for what was right.
# Lesson: We should always try to help those who are less fortunate than us, just like Abū Bakr did.
# Panels: 46
# -----------------------------------------------------------------
#
#   PANEL 1
#   Reader text: Abu Bakr was deeply concerned when he heard the news about 'Amir ibn Fuhayrah's enslavement.
#   Image prompt (116w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure sits in his home, reading a message or hearing news...
#
#   PANEL 2
#   Reader text: Abu Bakr met with al-Hafayl ibn Abdulla al-Asdi to discuss the spread of Islam. Despite initial doubts, Abu Bakr remained determined to share the message with others.
#   Image prompt (117w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: Abu Bakr and al-Hafayl ibn Abdulla al-Asdi standing in a bustling mark...
#
#   PANEL 3
#   Reader text: Abu Bakr was pleased to buy 'Amir ibn Fuhayrah from his master, showing kindness and compassion.
#   Image prompt (165w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. A marketplace or public meeting place in early Makkah with a mix of pa...
#
#   PANEL 4
#   Reader text: Abu Bakr stood tall, his eyes shining with determination as he approached 'Amir ibn Fuhayrah. With a gentle yet firm gesture, he released the rope that bound his friend, setting him free.
#   Image prompt (179w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: a public place, such as a square or a park, with a few palm t...
#
#   PANEL 5
#   Reader text: Abu Bakr and 'Amir ibn Fuhayrah met and became fast friends, united by their love of the Prophet and their desire to serve Allah.
#   Image prompt (144w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: The home of a central figure, a warm and cozy interior with a...
#
#   PANEL 6
#   Reader text: The Prophet sat in the cave, deep in thought. Suddenly, he felt a gentle touch on his shoulder. He turned to see the angel Jibril standing before him, holding a scroll. The Prophet's eyes widened as he read the words of the revelation.
#   Image prompt (88w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a dimly lit cave, the central figure sits on a rock, looking surpri...
#
#   PANEL 7
#   Reader text: Abu Bakr was deeply concerned when he heard about the revelation. He decided to help the Prophet and support him in his message.
#   Image prompt (76w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The setting is a simple house in Makkah with a few furnishings and obj...
#
#   PANEL 8
#   Reader text: Abu Bakr and the Prophet were excitedly preparing for their journey to Madinah. They were packing their bags and saying goodbye to their families.
#   Image prompt (197w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a cozy house in Makkah, Abu Bakr and the central figure are packing...
#
#   PANEL 9
#   Reader text: Abu Bakr and the Prophet were riding their camels through the desert when a fierce storm hit, making their journey even more difficult.
#   Image prompt (101w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The desert road stretches out before Abu Bakr and the central figure, ...
#
#   PANEL 10
#   Reader text: Abu Bakr and the Prophet rode their camels into Madinah, where they were greeted with joy by the people.
#   Image prompt (141w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. A street in Madinah, with Abu Bakr and the central figure riding camel...
#
#   PANEL 11
#   Reader text: Abu Bakr watched in horror as Abu Jahl tortured Zunayrah, feeling helpless to stop the cruel act.
#   Image prompt (111w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. A desert landscape with palm trees and rocky formations in the backgro...
#
#   PANEL 12
#   Reader text: Abu Bakr stood tall in the desert, his heart filled with courage and determination. He knew he had to rescue Zunayrah, the young woman captured by the Makhzum clan.
#   Image prompt (114w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The setting is a desert landscape with palm trees and rocks, near a sm...
#
#   PANEL 13
#   Reader text: Abu Bakr stood tall, looking Abu Jahl straight in the eye. 'Leave him alone!' he said firmly. Abu Jahl sneered, but Abu Bakr's confidence made him back down.
#   Image prompt (111w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A desert landscape with palm trees and rocks in the background. In the...
#
#   PANEL 14
#   Reader text: Abu Bakr saw Zunayrah being mistreated and decided to take action. He bravely approached the Makhzum clan and freed her from her chains, giving her the gift of freedom.
#   Image prompt (107w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: Abu Bakr, the central figure seen from behind, is shown breaking the c...
#
#   PANEL 15
#   Reader text: Zunayrah was overjoyed when Abu Bakr freed her from slavery. She thanked him with a big hug.
#   Image prompt (124w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert landscape near the Makhzum clan, with a f...
#
#   PANEL 16
#   Reader text: Abu Bakr heard about the mistreatment of al-Nahdiyah, a young woman, and felt worried and concerned.
#   Image prompt (114w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: In a bustling marketplace in Medina, the central figure stands out, lo...
#
#   PANEL 17
#   Reader text: Abu Bakr sat in quiet contemplation, weighing his options. He thought of al-Nahdiyah and her daughter, and his determination grew. He knew he had to act.
#   Image prompt (99w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure sits in a private area, possibly his home, with a d...
#
#   PANEL 18
#   Reader text: Abu Bakr was relieved to finally buy al-Nahdiyah and her daughter from their cruel mistress.
#   Image prompt (130w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a bustling marketplace in Medina, the central figure stands tall, m...
#
#   PANEL 19
#   Reader text: Al-Nahdiyah and her daughter were finally free from their ordeal. They hugged each other tightly, tears of joy streaming down their faces.
#   Image prompt (86w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A quiet, peaceful area with a few palm trees and a distant mountain ra...
#
#   PANEL 20
#   Reader text: Abu Bakr welcomed al-Nahdiyah and her daughter into his home with a warm smile.
#   Image prompt (184w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: The home of a revered central figure, a simple yet cozy room ...
#
#   PANEL 21
#   Reader text: Abu Bakr watched in the distance as Umm Ubays was being tortured by her master.
#   Image prompt (106w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A bustling marketplace in Medina, with people milling about i...
#
#   PANEL 22
#   Reader text: Abu Bakr decided to buy Umm Ubays from her master because he wanted to show kindness to her.
#   Image prompt (128w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A marketplace in Medina, afternoon sun casting a warm gentle light on ...
#
#   PANEL 23
#   Reader text: Abu Bakr was overjoyed to have rescued Umm Ubays from her difficult situation. He took her to safety and ensured her well-being.
#   Image prompt (205w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A bustling marketplace in Medina, with people milling about a...
#
#   PANEL 24
#   Reader text: Abu Bakr, the faithful companion of the Prophet, sets Umm Ubays free from her chains, bringing joy and gratitude to her heart.
#   Image prompt (139w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a quiet area outside Medina, late afternoon, the central figure is ...
#
#   PANEL 25
#   Reader text: Umm Ubays was overjoyed when Abu Bakr freed her from slavery. She thanked him with a warm hug, grateful for his kindness and generosity.
#   Image prompt (146w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A quiet area outside Medina, late afternoon. The central figure, mediu...
#
#   PANEL 26
#   Reader text: Abu Bakr was known for his kindness and generosity. One day, he decided to buy a slave from the clan of 'Adiy, showing his compassion and care for all people.
#   Image prompt (82w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a bustling marketplace, with Abu Bakr and the slav...
#
#   PANEL 27
#   Reader text: Abu Bakr listened with concern as a Muslim shared stories of the slave's miserable condition, sparking a desire to help.
#   Image prompt (118w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a bustling marketplace with people milling about i...
#
#   PANEL 28
#   Reader text: Abu Bakr was known for his kindness and compassion. When he saw the slave girl, he knew he had to help her.
#   Image prompt (119w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a bustling marketplace, the central figure stands out with his dign...
#
#   PANEL 29
#   Reader text: Abu Bakr was relieved to finally buy the slave from the clan of 'Adiy, ensuring the slave's freedom and happiness.
#   Image prompt (144w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In a bustling marketplace, the central figure is shown handing over a ...
#
#   PANEL 30
#   Reader text: Abu Bakr was so moved by the Prophet's words that he decided to set his slave free, showing his commitment to the message of Islam.
#   Image prompt (103w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a bustling marketplace with people of all ages and...
#
#   PANEL 31
#   Reader text: Umar ibn al-Khatab looked unhappy and disapproving as he watched Abu Bakr's actions in the marketplace.
#   Image prompt (95w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure of Umar ibn al-Khatab stands in the marketplace, lo...
#
#   PANEL 32
#   Reader text: Abu Bakr showed great kindness by setting free weak slaves, showing that all creatures deserve compassion and respect.
#   Image prompt (128w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: The central figure stands in a desert or marketplace setting, surround...
#
#   PANEL 33
#   Reader text: Abu Bakr's father was surprised to see him freeing slaves. He had never seen his son show such kindness and compassion.
#   Image prompt (107w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert or marketplace, with Abu Bakr's father st...
#
#   PANEL 34
#   Reader text: Abu Bakr's father was not happy with his choice of faith. He wanted Abu Bakr to follow their family's tradition.
#   Image prompt (128w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In the desert or a marketplace, Abu Bakr's father is standing with his...
#
#   PANEL 35
#   Reader text: Abu Bakr's father looked at him with a puzzled expression, 'Why have you made this decision, Abu Bakr? Is it truly what you want?'
#   Image prompt (88w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. A desert or marketplace setting with the central figure's father quest...
#
#   PANEL 36
#   Reader text: Abu Bakr's father looked at him with disappointment in his eyes, shaking his head at Abu Bakr's actions.
#   Image prompt (116w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. In the scene, Abu Bakr's father is shown looking disappointed at Abu B...
#
#   PANEL 37
#   Reader text: The Prophet Muhammad stood in the Prophet's Mosque, looking out at the gathered crowd. He pointed to Abu Bakr, saying, 'This is my successor, my friend and companion.'
#   Image prompt (127w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene takes place in the Prophet's Mosque in Medina, with a large ...
#
#   PANEL 38
#   Reader text: Abu Bakr was taken aback when the Prophet asked him to take on the responsibility. He looked down, unsure if he was ready for the challenge.
#   Image prompt (84w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: Medina, the central figure's Mosque, a grand open courtyard with a lar...
#
#   PANEL 39
#   Reader text: The Prophet Muhammad smiled reassuringly at Abu Bakr, placing his hand on the young man's shoulder.
#   Image prompt (133w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in the Prophet's Mosque in Medina, with a simple whit...
#
#   PANEL 40
#   Reader text: Abu Bakr listened to the Prophet's words and nodded in agreement. He smiled, promising to fulfill his new responsibility.
#   Image prompt (136w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: Medina, the central figure's Mosque, a large open courtyard with a sim...
#
#   PANEL 41
#   Reader text: Abu Bakr was known for his kindness and fairness. One day, he saw a slave and a master standing together in the marketplace. He approached them with a warm smile and said, 'My dear friends, I see you both standing here. Let us talk and share our thoughts.'
#   Image prompt (97w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: Medina, marketplace, with a mix of sandy and cobblestone stre...
#
#   PANEL 42
#   Reader text: The followers of the new religion are inspired by Abu Bakr's example of kindness and generosity. They look up to him as a role model and strive to emulate his actions.
#   Image prompt (98w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in the Prophet's Mosque in Medina, with a large crowd...
#
#   PANEL 43
#   Reader text: Abu Bakr saw Bilal's potential and decided to free him from slavery, giving him a chance to learn and grow.
#   Image prompt (87w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A serene and vast ancient desert landscape with palm trees an...
#
#   PANEL 44
#   Reader text: Abu Bakr was known for his kindness and selflessness. One day, he saw Bilal being mistreated and decided to take action. Umar witnessed Abu Bakr's bravery and was inspired by his actions.
#   Image prompt (92w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: a sandy desert landscape with palm trees and rocks in the bac...
#
#   PANEL 45
#   Reader text: The Prophet's loyal companion, ʿ Umar, thinks deeply about Abu Bakr's selfless actions, feeling grateful for his kindness.
#   Image prompt (90w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A serene desert landscape with palm trees and a distant mountain range...
#
#   PANEL 46
#   Reader text: The Prophet's trusted companion, ʿ Umar, praises Abu Bakr for his selfless actions, highlighting his importance to the community.
#   Image prompt (77w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Ancient Arabia, desert landscape with palm trees and sand dunes in the...
#
# Conclusion: Abū Bakr's selfless actions inspired others to do the same. He showed everyone that helping others is a great way to please God and make the world a better place.
#
# =================================================================
# STORY: Bilal's Kindness Test
# =================================================================
# Introduction: Imagine you're walking with your friends, and you come across a place where some people you don't know are being buried. How would you feel? Bilal, a close friend of the Prophet Muhammad, had to make a difficult choice like this once.
# Lesson: Kindness can change people's hearts and help us become better friends.
# Panels: 19
# -----------------------------------------------------------------
#
#   PANEL 1
#   Reader text: Bilāl is planning his route to pass by the burial site of the Jews killed in the battle. He wants to show respect for the deceased.
#   Image prompt (119w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The setting is a desert or open land with a few palm trees and a dista...
#
#   PANEL 2
#   Reader text: The Prophet's cousin, Bilāl, was joining the Muslim army to fight alongside the Prophet.
#   Image prompt (169w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a small house or settlement, with a simple door an...
#
#   PANEL 3
#   Reader text: Bilāl and the women set off on their journey, passing by the burial site of the Jews killed in the battle.
#   Image prompt (135w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene shows Bilāl and a group of women walking in the desert, with...
#
#   PANEL 4
#   Reader text: When Ṣafiyyah saw the burial site, she started crying and lamenting. Her cousin was moved by her grief and felt sad too.
#   Image prompt (115w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert or open land with a burial site in the ba...
#
#   PANEL 5
#   Reader text: Bilāl led Ḥāṭib and her cousin through the desert, showing them the way to the burial site.
#   Image prompt (89w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert landscape with a distant ancient site in ...
#
#   PANEL 6
#   Reader text: When Bilāl saw the burial site, he began to cry. His cousin was surprised and asked why he was crying.
#   Image prompt (106w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene takes place in a desert setting with a burial site in the ba...
#
#   PANEL 7
#   Reader text: The Prophet approached Bilāl, looking disapproving. He had heard that Bilāl had been singing songs in the marketplace, which was not in line with the teachings of Islam.
#   Image prompt (78w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert environment with a burial site in the bac...
#
#   PANEL 8
#   Reader text: The Prophet looked at Bilāl with a stern expression, pointing at him with a gentle but firm gesture. 'Bilāl, what have you done?' he asked, his voice filled with disappointment.
#   Image prompt (135w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert landscape with a burial site in the backg...
#
#   PANEL 9
#   Reader text: The Prophet looked at Bilāl with kindness, but Bilāl felt ashamed of his actions.
#   Image prompt (184w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert landscape with a burial site in the backg...
#
#   PANEL 10
#   Reader text: The Prophet looked at Bilāl with a stern expression, saying, 'What have you done? You must follow my guidance.' Bilāl looked down, ashamed.
#   Image prompt (108w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert or open area with a few palm trees or roc...
#
#   PANEL 11
#   Reader text: Bilāl felt ashamed of his actions and looked down, feeling embarrassed.
#   Image prompt (97w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A desert or open area with a few palm trees in the background, the cen...
#
#   PANEL 12
#   Reader text: Bilāl sat in contemplation, thinking deeply about his actions and their consequences.
#   Image prompt (81w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Show Bilāl sitting on a rock or a bundle of clothes in a desert or ope...
#
#   PANEL 13
#   Reader text: Bilāl felt sorry for his actions and wanted to make things right with the Prophet. He approached the Prophet with his hands clasped together in a gesture of apology.
#   Image prompt (138w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a desert or open area with a few palm trees in the...
#
#   PANEL 14
#   Reader text: The Prophet looked at Bilal with a serious expression, and Bilal felt a surge of determination. He knew he had to make things right.
#   Image prompt (97w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The setting is a desert or open area with a few palm trees in the back...
#
#   PANEL 15
#   Reader text: The Prophet saw his companion being harsh with the Jews in the marketplace. He felt concerned for their well-being and decided to speak with his companion.
#   Image prompt (117w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A bustling marketplace in Medina with people of all ages and ...
#
#   PANEL 16
#   Reader text: The Prophet gently yet firmly reproached his companion for his behavior, reminding him of the importance of self-control and respect for his guidance.
#   Image prompt (143w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. Setting: A quiet area in the marketplace, with a few palm trees and a ...
#
#   PANEL 17
#   Reader text: The Prophet stood in the marketplace, surrounded by people from all walks of life. He pointed to a nearby Jew, saying, 'Treating our enemies with kindness is a sign of wisdom and compassion. Let us always remember to show mercy and respect to those who may disagree with us.'
#   Image prompt (92w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a bustling marketplace in Medina, with people of a...
#
#   PANEL 18
#   Reader text: The Prophet's words touched the companion's heart, and he realized the error of his ways. He felt a deep sense of regret and made a promise to change his behavior.
#   Image prompt (118w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12. The scene is set in a quiet area of the marketplace, with a few palm t...
#
#   PANEL 19
#   Reader text: The Prophet and his companion visited the Jews in the marketplace, shaking hands with them and speaking kindly.
#   Image prompt (102w): Children's watercolor storybook illustration, soft warm hand-painted style for ages 6-12: A bustling marketplace in Medina, with the central figure and his comp...
#
# Conclusion: Bilal learned an important lesson that day: even if someone has done something wrong to you, you should still be kind to them. The Prophet Muhammad taught us that kindness can bring people together and make the world a better place.

# %%
# Download everything
import shutil
shutil.make_archive('golden_output', 'zip', 'golden_output')
from google.colab import files
files.download('golden_output.zip')
print('Downloaded golden_output.zip')
print('Each story JSON now has: story_context (title/intro/lesson/conclusion) + panels (each with narrative_text + image_prompt)')
# Out:
# Downloaded golden_output.zip
# Each story JSON now has: story_context (title/intro/lesson/conclusion) + panels (each with narrative_text + image_prompt)
